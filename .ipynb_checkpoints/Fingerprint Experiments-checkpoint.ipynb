# %%
import src.Functions as Fu
import src.Filter as Ft
import src.getFingerprint as gF
import src.maindir as md
import src.extraUtils as eu
import numpy as np
import os
import cv2 as cv

# %% [markdown]
# Эксперимент 1: Сравнение изображений из изначальной выборки, p1-p3 - образнцы снимков камеры, pxxx - снимок, принадлежность которого

# %%
im1 = 'Images'+os.sep+'P1.jpg'
im2 = 'Images'+os.sep+'P2.jpg'
im3 = 'Images'+os.sep+'P3.jpg'
Images = [im1, im2, im3]

# %%
RP,_,_ = gF.getFingerprint(Images)
RP = Fu.rgb2gray1(RP)
sigmaRP = np.std(RP)
Fingerprint = Fu.WienerInDFT(RP, sigmaRP)
# Out:
# *   2   *

# %%
imx = 'Images'+os.sep+'Pxxx.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))

# %%
Ix = cv.cvtColor(cv.imread(imx), cv.COLOR_BGR2GRAY)

# %%
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 201.9313890273873
# pvalue: 3.956757695302438e-46
# PeakLocation: [0, 0]
# peakheight: 0.016602956911497678
# P_FA: 3.956757695302438e-46
# log10P_FA: -45.402660544329656

# %%
imx = 'Images'+os.sep+'Pyyy.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 0.022721930530852044
# pvalue: 0.4400912164881009
# PeakLocation: [0, 0]
# peakheight: 0.00016983306892036457
# P_FA: 0.4400912164881009
# log10P_FA: -0.3564572991689708

# %%
imx = 'Images'+os.sep+'Pzzz.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 7.704183564355594e-05
# pvalue: 0.4964983897863842
# PeakLocation: [0, 0]
# peakheight: 1.0324992966405924e-05
# P_FA: 0.49649838978638416
# log10P_FA: -0.3040821556439717

# %%
imx = 'Images'+os.sep+'P2.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 177385.0327975482
# pvalue: 0.0
# PeakLocation: [0, 0]
# peakheight: 0.49670225793797057
# P_FA: 0.0
# log10P_FA: -38521.69400652174

# %%
import skimage
from skimage import io
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean

from PIL import Image

# %%
img1 = io.imread(im1)
img2 = io.imread(im2)
img3 = io.imread(im3)

# %%
resc1 = resize(img1,(256,256), anti_aliasing=False)
resc1 = 255*resc1
resc1 = resc1.astype(np.uint8)
#resc1 = Image.fromarray(resc1,'RGB')
#resc1.show()

# %%
resc2 = resize(img2,(256,256), anti_aliasing=False)
resc2 = 255*resc2
resc2 = resc2.astype(np.uint8)
#resc2 = Image.fromarray(resc2,'RGB')
#resc2.show()

# %%
resc3 = resize(img3,(256,256), anti_aliasing=False)
resc3 = 255*resc3
resc3 = resc3.astype(np.uint8)
#resc3 = Image.fromarray(resc3,'RGB')
#resc3.show()

# %%
io.imsave('ReP1.jpg', resc1)
io.imsave('ReP2.jpg', resc2)
io.imsave('ReP3.jpg', resc3)

# %%
imx = 'Images'+os.sep+'Pzzz.jpg'
img4 = io.imread(imx)
resc1 = resc1 = resize(img4,(256,256), anti_aliasing=False)
resc1 = 255*resc1
resc1 = resc1.astype(np.uint8)
io.imsave('RePzzz.jpg', resc1)

# %%
im1 = 'Images'+os.sep+'ReP1.jpg'
im2 = 'Images'+os.sep+'ReP2.jpg'
im3 = 'Images'+os.sep+'ReP3.jpg'
Images = [im1, 
          im2, 
          im3]

RP,_,_ = gF.getFingerprint(Images)
RP = Fu.rgb2gray1(RP)
sigmaRP = np.std(RP)
Fingerprint = Fu.WienerInDFT(RP, sigmaRP)

# To save RP in a '.mat' file:
#import scipy.io as sio
#sio.savemat('Fingerprint.mat', {'RP': RP, 'sigmaRP': sigmaRP, 'Fingerprint': Fingerprint})
# Out:
# *   2   *

# %%
imx = 'Images'+os.sep+'RePxxx.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 4.553804023082373
# pvalue: 0.016422847895320548
# PeakLocation: [0, 0]
# peakheight: 0.008795960589691778
# P_FA: 0.016422847895320558
# log10P_FA: -1.7845515294347707

# %%
imx = 'Images'+os.sep+'RePyyy.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: -5.083414308586185
# pvalue: 0.9879221217261981
# PeakLocation: [0, 0]
# peakheight: -0.009322975277196973
# P_FA: 0.9879221217261981
# log10P_FA: -0.0052772896609973126

# %%
imx = 'Images'+os.sep+'RePzzz.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 0.20123768365279784
# pvalue: 0.32686183637724553
# PeakLocation: [0, 0]
# peakheight: 0.0018497382778377362
# P_FA: 0.32686183637724553
# log10P_FA: -0.48563578366655485

# %%
imx = 'Images'+os.sep+'ReP2.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 13885.660512638653
# pvalue: 0.0
# PeakLocation: [0, 0]
# peakheight: 0.48957606607815574
# P_FA: 0.0
# log10P_FA: -3017.703242316143

# %%
im1 = 'Images'+os.sep+'ReP1.jpg'
im2 = 'Images'+os.sep+'ReP2.jpg'
im3 = 'Images'+os.sep+'ReP3.jpg'

# %%
img1 = io.imread(im1)
img2 = io.imread(im2)
img3 = io.imread(im3)

# %%
resc1 = resize(img1,(128,128), anti_aliasing=False)
resc1 = 255*resc1
resc1 = resc1.astype(np.uint8)
#resc1 = Image.fromarray(resc1,'RGB')
#resc1.show()

# %%
resc2 = resize(img2,(128,128), anti_aliasing=False)
resc2 = 255*resc2
resc2 = resc2.astype(np.uint8)
#resc2 = Image.fromarray(resc2,'RGB')
#resc2.show()

# %%
resc3 = resize(img3,(128,128), anti_aliasing=False)
resc3 = 255*resc3
resc3 = resc3.astype(np.uint8)
#resc3 = Image.fromarray(resc3,'RGB')
#resc3.show()

# %%
io.imsave('S1.jpg', resc1)
io.imsave('S2.jpg', resc2)
io.imsave('S3.jpg', resc3)

# %%
imx = 'Images'+os.sep+'RePyyy.jpg'
img4 = io.imread(imx)
resc1 = resc1 = resize(img4,(128,128), anti_aliasing=False)
resc1 = 255*resc1
resc1 = resc1.astype(np.uint8)
io.imsave('Syyy.jpg', resc1)

# %%
io.imsave('ReP1.jpg', resc1)
io.imsave('ReP2.jpg', resc2)
io.imsave('ReP3.jpg', resc3)

# %%
imx = 'Images'+os.sep+'Pzzz.jpg'
img4 = io.imread(imx)
resc1 = resc1 = resize(img4,(256,256), anti_aliasing=False)
resc1 = 255*resc1
resc1 = resc1.astype(np.uint8)
io.imsave('RePzzz.jpg', resc1)

# %%
im1 = 'Images'+os.sep+'ReeP1.jpg'
im2 = 'Images'+os.sep+'ReeP2.jpg'
im3 = 'Images'+os.sep+'ReeP3.jpg'
Images = [im1, 
          im2, 
          im3]

RP,_,_ = gF.getFingerprint(Images)
RP = Fu.rgb2gray1(RP)
sigmaRP = np.std(RP)
Fingerprint = Fu.WienerInDFT(RP, sigmaRP)

# To save RP in a '.mat' file:
#import scipy.io as sio
#sio.savemat('Fingerprint.mat', {'RP': RP, 'sigmaRP': sigmaRP, 'Fingerprint': Fingerprint})
# Out:
# *   2   *

# %%
imx = 'Images'+os.sep+'ReePxxx.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: -10.690897816020348
# pvalue: 0.9994616802868669
# PeakLocation: [0, 0]
# peakheight: -0.027196223540189912
# P_FA: 0.9994616802868669
# log10P_FA: -0.0002338522301950117

# %%
imx = 'Images'+os.sep+'ReePyyy.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: -0.6106436182144801
# pvalue: 0.7827272103038128
# PeakLocation: [0, 0]
# peakheight: -0.006593654168489338
# P_FA: 0.7827272103038128
# log10P_FA: -0.10638956834008922

# %%
imx = 'Images'+os.sep+'ReePzzz.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: -0.00021240369398121676
# pvalue: 0.5058140093312751
# PeakLocation: [0, 0]
# peakheight: -0.00012186789703836304
# P_FA: 0.5058140093312751
# log10P_FA: -0.29600914634192715

# %%
imx = 'Images'+os.sep+'ReeP2.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 3645.953283547163
# pvalue: 0.0
# PeakLocation: [0, 0]
# peakheight: 0.5054505369914398
# P_FA: 0.0
# log10P_FA: -793.8886916447855

# %%
# extracting Fingerprint from same size images in a path
im1 = 'Images'+os.sep+'RP1.jpg'
im2 = 'Images'+os.sep+'RP2.jpg'
im3 = 'Images'+os.sep+'RP3.jpg'
Images = [im1, 
          im2, 
          im3]

# %%
RP,_,_ = gF.getFingerprint(Images)
RP = Fu.rgb2gray1(RP)
sigmaRP = np.std(RP)
Fingerprint = Fu.WienerInDFT(RP, sigmaRP)

# To save RP in a '.mat' file:
#import scipy.io as sio
#sio.savemat('Fingerprint.mat', {'RP': RP, 'sigmaRP': sigmaRP, 'Fingerprint': Fingerprint})
# Out:
# *   2   *

# %%
imx = 'Images'+os.sep+'RPxxx.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 2.473822965355244
# pvalue: 0.0578780349106208
# PeakLocation: [0, 0]
# peakheight: 0.006448015109802637
# P_FA: 0.057878034910620824
# log10P_FA: -1.2374862225765237

# %%
imx = 'Images'+os.sep+'RPyyy.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: -0.2680187086773521
# pvalue: 0.697668026845066
# PeakLocation: [0, 0]
# peakheight: -0.0021444438402566488
# P_FA: 0.697668026845066
# log10P_FA: -0.15635117967663184

# %%
imx = 'Images'+os.sep+'RPzzz.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: -2.889363372135213
# pvalue: 0.9554169233908192
# PeakLocation: [0, 0]
# peakheight: -0.006987567965910039
# P_FA: 0.9554169233908192
# log10P_FA: -0.01980707028507633

# %%
imx = 'Images'+os.sep+'RP2.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))
# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)
C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 13363.82194976067
# pvalue: 0.0
# PeakLocation: [0, 0]
# peakheight: 0.48289760286793104
# P_FA: 0.0
# log10P_FA: -2904.3791202338707

# %%
im1 = 'Images'+os.sep+'P1.jpg'
im2 = 'Images'+os.sep+'Pxxx.jpg'
im3 = 'Images'+os.sep+'P3.jpg'
Images = [im1, im2, im3]

RP,_,_ = gF.getFingerprint(Images)
RP = Fu.rgb2gray1(RP)
sigmaRP = np.std(RP)
Fingerprint = Fu.WienerInDFT(RP, sigmaRP)

# To save RP in a '.mat' file:
#import scipy.io as sio
#sio.savemat('Fingerprint.mat', {'RP': RP, 'sigmaRP': sigmaRP, 'Fingerprint': Fingerprint})

imx = 'Images'+os.sep+'P2.jpg'
Noisex = Ft.NoiseExtractFromImage(imx, sigma=2.)
Noisex = Fu.WienerInDFT(Noisex, np.std(Noisex))

# The optimal detector (see publication "Large Scale Test of Sensor Fingerprint Camera Identification")
Ix = cv.cvtColor(cv.imread(imx),# image in BGR format
                 cv.COLOR_BGR2GRAY)

C = Fu.crosscorr(Noisex,np.multiply(Ix, Fingerprint))
det, det0 = md.PCE(C)
for key in det.keys(): print("{0}: {1}".format(key, det[key]))
eu.mesh(C)
# Out:
# PCE: 228.26111429863465
# pvalue: 7.137410785991598e-52
# PeakLocation: [0, 0]
# peakheight: 0.017525628339177715
# P_FA: 7.137410785991598e-52
# log10P_FA: -51.146459307172535
